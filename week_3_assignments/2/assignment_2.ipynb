# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('e-commerce.csv')

# %%
df.head()
# Out:
#    customerNumber                          productName  orderMonth  priceEach  \
# 0             363             1917 Grand Touring Sedan           1     136.00
# 1             363                   1911 Ford Town Car           1      55.09
# 2             363  1932 Alfa Romeo 8C2300 Spider Sport           1      75.46
# 3             363     1936 Mercedes Benz 500k Roadster           1      35.29
# 4             128            1932 Model A Ford J-Coupe           1     108.06
#
#    quantityOrdered  final_payment
# 0               30        4080.00
# 1               50        2754.50
# 2               22        1660.12
# 3               49        1729.21
# 4               25        2701.50

# %%
monthly_count = df.groupby(['productName', 'orderMonth']).agg({'quantityOrdered': 'sum', 'priceEach': 'mean'}).reset_index()
monthly_count
# Out:
#                               productName  orderMonth  quantityOrdered  \
# 0     18th Century Vintage Horse Carriage           1               95
# 1     18th Century Vintage Horse Carriage           2               35
# 2     18th Century Vintage Horse Carriage           3              103
# 3     18th Century Vintage Horse Carriage           4               63
# 4     18th Century Vintage Horse Carriage           5               51
# ...                                   ...         ...              ...
# 1296            The USS Constitution Ship           8               78
# 1297            The USS Constitution Ship           9               44
# 1298            The USS Constitution Ship          10              125
# 1299            The USS Constitution Ship          11              240
# 1300            The USS Constitution Ship          12               59
#
#       priceEach
# 0     88.663333
# 1     93.200000
# 2     99.483333
# 3     85.345000
# 4     95.820000
# ...

# %%
product_name = 'The USS Constitution Ship'

# %%
fig , ax = plt.subplots(figsize=(10,6))
ax.plot(monthly_count[monthly_count['productName'] == f'{product_name}']['orderMonth'], monthly_count[monthly_count['productName'] == f'{product_name}']['quantityOrdered'], color='#005f73', marker='o')
ax.fill_between(monthly_count[monthly_count['productName'] == f'{product_name}']['orderMonth'], 0, monthly_count[monthly_count['productName'] == f'{product_name}']['quantityOrdered'], color='#005f73', alpha=0.6)
ax.set_facecolor('#EAF4f4')
fig.set_facecolor('#EAF4f4')
ax.set_title('Monthly Quantity Ordered per Product')
ax.set_xlabel('Month')
ax.set_ylabel('Quantity Ordered')
ax.spines[['left', 'top']].set_visible(False)
ax.tick_params(length=0)
ax.yaxis.set_ticks_position('right')
plt.legend(loc='upper right', facecolor='#EAF4f4')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig , ax = plt.subplots(figsize=(10,6))
ax.plot(monthly_count[monthly_count['productName'] == f'{product_name}']['orderMonth'], monthly_count[monthly_count['productName'] == f'{product_name}']['priceEach'], color='#005f73', marker='o')
ax.set_facecolor('#EAF4f4')
fig.set_facecolor('#EAF4f4')
ax.set_title('Monthly Price Average')
ax.set_xlabel('Month')
ax.set_ylabel('Average Price ($)')
ax.spines[['left', 'top']].set_visible(False)
ax.tick_params(length=0)
ax.yaxis.set_ticks_position('right')
plt.grid(color='#EAF4f4', linestyle='-', linewidth=1)
plt.legend(loc='upper right', facecolor='#EAF4f4')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
